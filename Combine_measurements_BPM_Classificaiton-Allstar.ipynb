# %% [markdown]
# ### Loading in dependencies and defining machine learning function to automate the process of running models and obtaining performance metrics.

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, precision_recall_fscore_support,classification_report,confusion_matrix,ConfusionMatrixDisplay, plot_confusion_matrix
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
import lightgbm as lgb
from sklearn.naive_bayes import GaussianNB
import pickle5 as pickle
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from imblearn.over_sampling import RandomOverSampler
import seaborn as sns


def machine_learn(algorithm, X_train, X_test, y_train, y_test, algo_name="unknown"):
    
    
    
    #Fitting and predicting starts here
    algorithm.fit(X_train, y_train)
    preds = algorithm.predict(X_test)
    fpr, tpr, thresholds = metrics.roc_curve(y_test, algorithm.predict_proba(X_test)[:,1])
    J = tpr - fpr
    ix = np.argmax(J)
    best_thresh = thresholds[ix]
    preds_best_cutoff = pd.Series(preds).apply(lambda x: 1 if x > best_thresh else 0)
    preds_best_cutoff = preds_best_cutoff.tolist()
    a_score = accuracy_score(y_test, preds_best_cutoff)
    auc_value = roc_auc_score(y_test, preds_best_cutoff)
    print(classification_report(y_test,preds_best_cutoff))
    print("It has accuracy of {} AUC of {}".format(a_score,auc_value))
    
    
    #confusion matrix
    cm = confusion_matrix(y_test, preds_best_cutoff, labels=[0,1])
    print(cm)
    return fpr, tpr, auc_value
   
def plotImp(model, X , num = 20):
    feature_imp = pd.DataFrame(sorted(zip(model.feature_importance(),X.columns)), 
                               columns=['Value','Feature'])
    sns.barplot(x="Value", y="Feature", data=feature_imp.sort_values(by="Value", 
                                                        ascending=False)[0:num])
    print(feature_imp.sort_values(by="Value", 
                                                        ascending=False)[0:num])
    plt.title('LightGBM Features (avg over folds)')
    plt.tight_layout()
    plt.savefig('lgbm_importances-{}.png'.format(num))

# %% [markdown]
# ### Loading in and cleaning data set: The data set contains all of the NBA draft combine measurements for all players from 2000 to 2019 as well as their four-year-average Box Plus Minus (BPM). We would like to predict if a player's four-year-average BPM is >= 4 or <4. A BPM >= to 4 indicate the player is an All-Star consideration.

# %%
four_years_df = pd.read_pickle("cleaned_df.pkl")
four_years_df = four_years_df[four_years_df['MP']>250]
four_years_df = four_years_df.drop(['POS','Name','YEAR','Season','through_4_years','WITH SHOES','MP'],axis=1)
four_years_df = pd.get_dummies(four_years_df)
# Setting Avg_BPM >=0 as 1, and < 0 as 0
four_years_df['Avg_BPM'] = (four_years_df['Avg_BPM'] >= 4).astype(int)
#setting first year BPM >=0 as 1, and < 0 as 0.
four_years_df['BPM'] = (four_years_df['BPM'] >= 4).astype(int)

# %% [markdown]
# ###  Train-test split four - year average

# %%
train, test = train_test_split(four_years_df, test_size=0.3, random_state=42, stratify=four_years_df['Avg_BPM'])

print("Upsampling training...")  
ros = RandomOverSampler(sampling_strategy='minority')
X_train, y_train = ros.fit_resample(train.drop(['BPM','Avg_BPM'],axis=1), train['Avg_BPM'])
X_test = test.copy(deep=True).drop(['BPM','Avg_BPM'], axis=1)
y_test = test['Avg_BPM']
assert X_test.shape[0] == y_test.shape[0], "wrong shapes for test set"
assert X_train.shape[0] == y_train.shape[0], "wrong shapes for training set"
# Out:
# Upsampling training...

# %% [markdown]
# #### This part standarizes certain continues varaibles. This is important for algorithims like KNN and MLP.

# %% [markdown]
# ### Predicting four year average

# %%
plt.figure()

bayes = GaussianNB()
fpr, tpr, auc = machine_learn(bayes, X_train, X_test, y_train, y_test, "NaiveBayes")
plt.plot(fpr, tpr, label='%s ROC (area = %0.2f)' % ("Naive Bayes", auc))
print("Done with NB")

rf = RandomForestClassifier()
fpr, tpr, auc = machine_learn(rf, X_train, X_test, y_train, y_test, "RandomForest")
plt.plot(fpr, tpr, label='%s ROC (area = %0.2f)' % ("Random Forest", auc))
print("Done with rf")

adBoost = AdaBoostClassifier()
fpr, tpr, auc = machine_learn(adBoost, X_train, X_test, y_train, y_test, "AdaBoost")      
plt.plot(fpr, tpr, label='%s ROC (area = %0.2f)' % ("Ada Boost ", auc))
print("Done with adBoost")

svc =SVC(probability=True)
fpr, tpr, auc = machine_learn(svc, X_train, X_test, y_train, y_test, "SVC")      
plt.plot(fpr, tpr, label='%s ROC (area = %0.2f)' % ("Support Vector Machine ", auc))

lgb_train = lgb.Dataset(X_train, y_train)
lgb_eval = lgb.Dataset(X_test, y_test, reference=lgb_train)

# specify your configurations as a dict
params = {
    'boosting_type': 'gbdt',
    'objective': 'binary',
    'metric': {'l2', 'l1', "binary"},
  #  'metric': None,
    'num_leaves': 100,
    'learning_rate': 0.05,
    'feature_fraction': 0.9,
    'bagging_fraction': 0.8,
    'bagging_freq': 50,
    'verbose': -1
}

print('Starting training...')
# train
gbm = lgb.train(params,
                lgb_train,
             # feval=lgb_precision,
                num_boost_round=1000,
                valid_sets=lgb_eval,
                early_stopping_rounds=5)




print('Starting predicting...')
# predict
preds_proba = gbm.predict(X_test, num_iteration=gbm.best_iteration) 
fpr, tpr, thresholds = metrics.roc_curve(y_test,preds_proba)
J = tpr - fpr
ix = np.argmax(J)
best_thresh = thresholds[ix]
preds_best_cutoff = pd.Series(preds_proba).apply(lambda x: 1 if x > best_thresh else 0)
preds_best_cutoff = preds_best_cutoff.tolist()
a_score = accuracy_score(y_test, preds_best_cutoff)
auc_value = roc_auc_score(y_test, preds_best_cutoff)
print(classification_report(y_test,preds_best_cutoff))
print("It has accuracy of {} AUC of {}".format(a_score,auc_value))
plt.plot(fpr, tpr, label='%s ROC (area = %0.2f)' % ("Light GBM ", auc_value))

plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
# Out:
# C:\Users\kylek\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kylek\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kylek\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kylek\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kylek\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kylek\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99       161
#            1       0.00      0.00      0.00         2
#
#     accuracy                           0.99       163
#    macro avg       0.49      0.50      0.50       163
# weighted avg       0.98      0.99      0.98       163
#
# It has accuracy of 0.9877300613496932 AUC of 0.5
# [[161   0]
#  [  2   0]]
# Done with NB
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99       161
#            1       0.00      0.00      0.00         2
#
#     accuracy                           0.99       163
#    macro avg       0.49      0.50      0.50       163
# weighted avg       0.98      0.99      0.98       163
#
# It has accuracy of 0.9877300613496932 AUC of 0.5
# [[161   0]
#  [  2   0]]
# Done with rf
# C:\Users\kylek\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kylek\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kylek\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99       161
#            1       0.00      0.00      0.00         2
#
#     accuracy                           0.99       163
#    macro avg       0.49      0.50      0.50       163
# weighted avg       0.98      0.99      0.98       163
#
# It has accuracy of 0.9877300613496932 AUC of 0.5
# [[161   0]
#  [  2   0]]
# Done with adBoost
#               precision    recall  f1-score   support
#
#            0       0.96      0.31      0.47       161
#            1       0.00      0.00      0.00         2
#
#     accuracy                           0.31       163
#    macro avg       0.48      0.16      0.23       163
# weighted avg       0.95      0.31      0.46       163
#
# It has accuracy of 0.3067484662576687 AUC of 0.15527950310559008
# [[ 50 111]
#  [  2   0]]
# Starting training...
# [1]	valid_0's l2: 0.227872	valid_0's l1: 0.477257	valid_0's binary_logloss: 0.648854
# Training until validation scores don't improve for 5 rounds
# [2]	valid_0's l2: 0.208452	valid_0's l1: 0.456252	valid_0's binary_logloss: 0.609794
# [3]	valid_0's l2: 0.191662	valid_0's l1: 0.437158	valid_0's binary_logloss: 0.575732
# [4]	valid_0's l2: 0.175909	valid_0's l1: 0.418218	valid_0's binary_logloss: 0.543373
# [5]	valid_0's l2: 0.163178	valid_0's l1: 0.402148	valid_0's binary_logloss: 0.51681
# [6]	valid_0's l2: 0.150282	valid_0's l1: 0.384995	valid_0's binary_logloss: 0.489456
# [7]	valid_0's l2: 0.138751	valid_0's l1: 0.368722	valid_0's binary_logloss: 0.464463
# [8]	valid_0's l2: 0.128446	valid_0's l1: 0.35328	valid_0's binary_logloss: 0.441579
# [9]	valid_0's l2: 0.118861	valid_0's l1: 0.33871	valid_0's binary_logloss: 0.419931
# [10]	valid_0's l2: 0.110518	valid_0's l1: 0.324712	valid_0's binary_logloss: 0.400379
# [11]	valid_0's l2: 0.102878	valid_0's l1: 0.311783	valid_0's binary_logloss: 0.382134
# [12]	valid_0's l2: 0.0958718	valid_0's l1: 0.299111	valid_0's binary_logloss: 0.364891
# [13]	valid_0's l2: 0.0896024	valid_0's l1: 0.28708	valid_0's binary_logloss: 0.348949
# [14]	valid_0's l2: 0.0841649	valid_0's l1: 0.275613	valid_0's binary_logloss: 0.334459
# [15]	valid_0's l2: 0.0789503	valid_0's l1: 0.264925	valid_0's binary_logloss: 0.320468
# [16]	valid_0's l2: 0.0744833	valid_0's l1: 0.254622	valid_0's binary_logloss: 0.307847
# [17]	valid_0's l2: 0.0705634	valid_0's l1: 0.244724	valid_0's binary_logloss: 0.296152
# [18]	valid_0's l2: 0.0671237	valid_0's l1: 0.235358	valid_0's binary_logloss: 0.285396
# [19]	valid_0's l2: 0.0632247	valid_0's l1: 0.225863	valid_0's binary_logloss: 0.273746
# [20]	valid_0's l2: 0.0604992	valid_0's l1: 0.217382	valid_0's binary_logloss: 0.264411
# [21]	valid_0's l2: 0.0573714	valid_0's l1: 0.209139	valid_0's binary_logloss: 0.254422
# [22]	valid_0's l2: 0.0548373	valid_0's l1: 0.201241	valid_0's binary_logloss: 0.245486
# [23]	valid_0's l2: 0.0522443	valid_0's l1: 0.193762	valid_0's binary_logloss: 0.236666
# [24]	valid_0's l2: 0.0506058	valid_0's l1: 0.187002	valid_0's binary_logloss: 0.229782
# [25]	valid_0's l2: 0.0487543	valid_0's l1: 0.180244	valid_0's binary_logloss: 0.222478
# [26]	valid_0's l2: 0.0470694	valid_0's l1: 0.173726	valid_0's binary_logloss: 0.215498
# [27]	valid_0's l2: 0.0448575	valid_0's l1: 0.167591	valid_0's binary_logloss: 0.207841
# [28]	valid_0's l2: 0.0430787	valid_0's l1: 0.161277	valid_0's binary_logloss: 0.200932
# [29]	valid_0's l2: 0.0422627	valid_0's l1: 0.156048	valid_0's binary_logloss: 0.19611
# [30]	valid_0's l2: 0.0411605	valid_0's l1: 0.150686	valid_0's binary_logloss: 0.190694
# [31]	valid_0's l2: 0.0406369	valid_0's l1: 0.146033	valid_0's binary_logloss: 0.186686
# [32]	valid_0's l2: 0.0389365	valid_0's l1: 0.140989	valid_0's binary_logloss: 0.180443
# [33]	valid_0's l2: 0.0372905	valid_0's l1: 0.13539	valid_0's binary_logloss: 0.174033
# [34]	valid_0's l2: 0.0362439	valid_0's l1: 0.130631	valid_0's binary_logloss: 0.169235
# [35]	valid_0's l2: 0.0348307	valid_0's l1: 0.125531	valid_0's binary_logloss: 0.163523
# [36]	valid_0's l2: 0.0333752	valid_0's l1: 0.120576	valid_0's binary_logloss: 0.157881
# [37]	valid_0's l2: 0.0320327	valid_0's l1: 0.115859	valid_0's binary_logloss: 0.152596
# [38]	valid_0's l2: 0.0313215	valid_0's l1: 0.111968	valid_0's binary_logloss: 0.148874
# [39]	valid_0's l2: 0.030642	valid_0's l1: 0.10873	valid_0's binary_logloss: 0.145462
# [40]	valid_0's l2: 0.0295296	valid_0's l1: 0.1046	valid_0's binary_logloss: 0.140964
# [41]	valid_0's l2: 0.0283227	valid_0's l1: 0.100506	valid_0's binary_logloss: 0.136306
# [42]	valid_0's l2: 0.0275445	valid_0's l1: 0.0971389	valid_0's binary_logloss: 0.132732
# [43]	valid_0's l2: 0.0267783	valid_0's l1: 0.0938279	valid_0's binary_logloss: 0.129263
# [44]	valid_0's l2: 0.0261322	valid_0's l1: 0.0907833	valid_0's binary_logloss: 0.126181
# [45]	valid_0's l2: 0.0254883	valid_0's l1: 0.0875603	valid_0's binary_logloss: 0.123066
# [46]	valid_0's l2: 0.0248792	valid_0's l1: 0.0844899	valid_0's binary_logloss: 0.120029
# [47]	valid_0's l2: 0.0240898	valid_0's l1: 0.0815051	valid_0's binary_logloss: 0.116886
# [48]	valid_0's l2: 0.0234102	valid_0's l1: 0.0787655	valid_0's binary_logloss: 0.114108
# [49]	valid_0's l2: 0.0230825	valid_0's l1: 0.0764725	valid_0's binary_logloss: 0.112107
# [50]	valid_0's l2: 0.0223332	valid_0's l1: 0.0738893	valid_0's binary_logloss: 0.1094
# [51]	valid_0's l2: 0.021941	valid_0's l1: 0.0717778	valid_0's binary_logloss: 0.107537
# [52]	valid_0's l2: 0.0216001	valid_0's l1: 0.0697954	valid_0's binary_logloss: 0.105858
# [53]	valid_0's l2: 0.0212796	valid_0's l1: 0.0678918	valid_0's binary_logloss: 0.104292
# [54]	valid_0's l2: 0.021028	valid_0's l1: 0.0661347	valid_0's binary_logloss: 0.102935
# [55]	valid_0's l2: 0.020791	valid_0's l1: 0.0644441	valid_0's binary_logloss: 0.101673
# [56]	valid_0's l2: 0.0206179	valid_0's l1: 0.062893	valid_0's binary_logloss: 0.100606
# [57]	valid_0's l2: 0.0204416	valid_0's l1: 0.0613402	valid_0's binary_logloss: 0.0995463
# [58]	valid_0's l2: 0.0203234	valid_0's l1: 0.059958	valid_0's binary_logloss: 0.0987124
# [59]	valid_0's l2: 0.0198717	valid_0's l1: 0.0579629	valid_0's binary_logloss: 0.0969753
# [60]	valid_0's l2: 0.0197825	valid_0's l1: 0.0566935	valid_0's binary_logloss: 0.0962961
# [61]	valid_0's l2: 0.0197224	valid_0's l1: 0.0555451	valid_0's binary_logloss: 0.0957688
# [62]	valid_0's l2: 0.0196861	valid_0's l1: 0.0544329	valid_0's binary_logloss: 0.095306
# [63]	valid_0's l2: 0.0196262	valid_0's l1: 0.0534238	valid_0's binary_logloss: 0.0949115
# [64]	valid_0's l2: 0.0195669	valid_0's l1: 0.0523333	valid_0's binary_logloss: 0.0944361
# [65]	valid_0's l2: 0.019333	valid_0's l1: 0.0511043	valid_0's binary_logloss: 0.0936458
# [66]	valid_0's l2: 0.0193304	valid_0's l1: 0.0502813	valid_0's binary_logloss: 0.09349
# [67]	valid_0's l2: 0.0193316	valid_0's l1: 0.0493984	valid_0's binary_logloss: 0.0932914
# [68]	valid_0's l2: 0.0193452	valid_0's l1: 0.0485593	valid_0's binary_logloss: 0.0931509
# [69]	valid_0's l2: 0.0191162	valid_0's l1: 0.0472273	valid_0's binary_logloss: 0.0922082
# [70]	valid_0's l2: 0.019117	valid_0's l1: 0.0460988	valid_0's binary_logloss: 0.0918174
# [71]	valid_0's l2: 0.0191071	valid_0's l1: 0.0449752	valid_0's binary_logloss: 0.0914198
# [72]	valid_0's l2: 0.0189602	valid_0's l1: 0.0440899	valid_0's binary_logloss: 0.0910373
# [73]	valid_0's l2: 0.0188771	valid_0's l1: 0.0431895	valid_0's binary_logloss: 0.0907378
# [74]	valid_0's l2: 0.0187246	valid_0's l1: 0.0422428	valid_0's binary_logloss: 0.0903102
# [75]	valid_0's l2: 0.0187499	valid_0's l1: 0.0413389	valid_0's binary_logloss: 0.0901676
# [76]	valid_0's l2: 0.0187073	valid_0's l1: 0.0407419	valid_0's binary_logloss: 0.0900756
# [77]	valid_0's l2: 0.0187408	valid_0's l1: 0.0399327	valid_0's binary_logloss: 0.0900072
# [78]	valid_0's l2: 0.0186394	valid_0's l1: 0.0392644	valid_0's binary_logloss: 0.0898855
# [79]	valid_0's l2: 0.0185551	valid_0's l1: 0.0386711	valid_0's binary_logloss: 0.0898596
# [80]	valid_0's l2: 0.0186519	valid_0's l1: 0.0381033	valid_0's binary_logloss: 0.0901233
# [81]	valid_0's l2: 0.0187121	valid_0's l1: 0.0374094	valid_0's binary_logloss: 0.0902317
# [82]	valid_0's l2: 0.0187763	valid_0's l1: 0.0367249	valid_0's binary_logloss: 0.0903574
# [83]	valid_0's l2: 0.0186954	valid_0's l1: 0.0361973	valid_0's binary_logloss: 0.0903986
# [84]	valid_0's l2: 0.0187656	valid_0's l1: 0.0355956	valid_0's binary_logloss: 0.0906167
# Early stopping, best iteration is:
# [79]	valid_0's l2: 0.0185551	valid_0's l1: 0.0386711	valid_0's binary_logloss: 0.0898596
# Starting predicting...
#               precision    recall  f1-score   support
#
#            0       0.99      0.47      0.64       161
#            1       0.01      0.50      0.02         2
#
#     accuracy                           0.47       163
#    macro avg       0.50      0.49      0.33       163
# weighted avg       0.98      0.47      0.63       163
#
# It has accuracy of 0.4723926380368098 AUC of 0.4860248447204969

# %%
explainer = shap.TreeExplainer(gbm)
shap_values = explainer.shap_values(X_train)
shap.summary_plot(shap_values, X_train)
# Out:
# LightGBM binary classifier with TreeExplainer shap values output has changed to a list of ndarray

# %% [markdown]
# ###  Train-test split first year BPM

# %%
train, test = train_test_split(four_years_df, test_size=0.3, random_state=42, stratify=four_years_df['BPM'])

print("Upsampling training...")  
ros = RandomOverSampler(sampling_strategy='minority')
X_train, y_train = ros.fit_resample(train.drop(['BPM','Avg_BPM'],axis=1), train['BPM'])
X_test = test.copy(deep=True).drop(['BPM','Avg_BPM'], axis=1)
y_test = test['BPM']
assert X_test.shape[0] == y_test.shape[0], "wrong shapes for test set"
assert X_train.shape[0] == y_train.shape[0], "wrong shapes for training set"
# Out:
# Upsampling training...

# %% [markdown]
# ### Predicting first-year BPM

# %%
plt.figure()

bayes = GaussianNB()
fpr, tpr, auc = machine_learn(bayes, X_train, X_test, y_train, y_test, "NaiveBayes")
plt.plot(fpr, tpr, label='%s ROC (area = %0.2f)' % ("Naive Bayes", auc))
print("Done with NB")

rf = RandomForestClassifier()
fpr, tpr, auc = machine_learn(rf, X_train, X_test, y_train, y_test, "RandomForest")
plt.plot(fpr, tpr, label='%s ROC (area = %0.2f)' % ("Random Forest", auc))
print("Done with rf")

adBoost = AdaBoostClassifier()
fpr, tpr, auc = machine_learn(adBoost, X_train, X_test, y_train, y_test, "AdaBoost")      
plt.plot(fpr, tpr, label='%s ROC (area = %0.2f)' % ("Ada Boost ", auc))
print("Done with adBoost")

svc =SVC(probability=True)
fpr, tpr, auc = machine_learn(svc, X_train, X_test, y_train, y_test, "SVC")      
plt.plot(fpr, tpr, label='%s ROC (area = %0.2f)' % ("Support Vector Machine ", auc))

lgb_train = lgb.Dataset(X_train, y_train)
lgb_eval = lgb.Dataset(X_test, y_test, reference=lgb_train)

# specify your configurations as a dict
params = {
    'boosting_type': 'gbdt',
    'objective': 'binary',
    'metric': {'l2', 'l1', "binary"},
  #  'metric': None,
    'num_leaves': 100,
    'learning_rate': 0.05,
    'feature_fraction': 0.9,
    'bagging_fraction': 0.8,
    'bagging_freq': 50,
    'verbose': -1
}

print('Starting training...')
# train
gbm = lgb.train(params,
                lgb_train,
             # feval=lgb_precision,
                num_boost_round=1000,
                valid_sets=lgb_eval,
                early_stopping_rounds=5)




print('Starting predicting...')
# predict
preds_proba = gbm.predict(X_test, num_iteration=gbm.best_iteration) 
fpr, tpr, thresholds = metrics.roc_curve(y_test,preds_proba)
J = tpr - fpr
ix = np.argmax(J)
best_thresh = thresholds[ix]
preds_best_cutoff = pd.Series(preds_proba).apply(lambda x: 1 if x > best_thresh else 0)
c = preds_best_cutoff.tolist()
a_score = accuracy_score(y_test, preds_best_cutoff)
auc_value = roc_auc_score(y_test, preds_best_cutoff)
print(classification_report(y_test,preds_best_cutoff))
print("It has accuracy of {} AUC of {}".format(a_score,auc_value))
plt.plot(fpr, tpr, label='%s ROC (area = %0.2f)' % ("Light GBM ", auc_value))

plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
# Out:
# C:\Users\kylek\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kylek\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kylek\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kylek\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kylek\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kylek\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       162
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.99       163
#    macro avg       0.50      0.50      0.50       163
# weighted avg       0.99      0.99      0.99       163
#
# It has accuracy of 0.9938650306748467 AUC of 0.5
# [[162   0]
#  [  1   0]]
# Done with NB
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       162
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.99       163
#    macro avg       0.50      0.50      0.50       163
# weighted avg       0.99      0.99      0.99       163
#
# It has accuracy of 0.9938650306748467 AUC of 0.5
# [[162   0]
#  [  1   0]]
# Done with rf
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       162
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.98       163
#    macro avg       0.50      0.49      0.50       163
# weighted avg       0.99      0.98      0.98       163
#
# It has accuracy of 0.9815950920245399 AUC of 0.49382716049382713
# [[160   2]
#  [  1   0]]
# Done with adBoost
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       162
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.99       163
#    macro avg       0.50      0.50      0.50       163
# weighted avg       0.99      0.99      0.99       163
#
# It has accuracy of 0.9938650306748467 AUC of 0.5
# [[162   0]
#  [  1   0]]
# Starting training...
# [1]	valid_0's l2: 0.226258	valid_0's l1: 0.475634	valid_0's binary_logloss: 0.645624
# Training until validation scores don't improve for 5 rounds
# [2]	valid_0's l2: 0.204905	valid_0's l1: 0.452538	valid_0's binary_logloss: 0.602679
# [3]	valid_0's l2: 0.185693	valid_0's l1: 0.430637	valid_0's binary_logloss: 0.563691
# [4]	valid_0's l2: 0.1684	valid_0's l1: 0.409861	valid_0's binary_logloss: 0.52815
# [5]	valid_0's l2: 0.15283	valid_0's l1: 0.390147	valid_0's binary_logloss: 0.49564
# [6]	valid_0's l2: 0.138515	valid_0's l1: 0.371198	valid_0's binary_logloss: 0.465196
# [7]	valid_0's l2: 0.125874	valid_0's l1: 0.353429	valid_0's binary_logloss: 0.437718
# [8]	valid_0's l2: 0.114487	valid_0's l1: 0.336559	valid_0's binary_logloss: 0.412378
# [9]	valid_0's l2: 0.104228	valid_0's l1: 0.320539	valid_0's binary_logloss: 0.388961
# [10]	valid_0's l2: 0.0948419	valid_0's l1: 0.305312	valid_0's binary_logloss: 0.366977
# [11]	valid_0's l2: 0.0865017	valid_0's l1: 0.290853	valid_0's binary_logloss: 0.346832
# [12]	valid_0's l2: 0.0789878	valid_0's l1: 0.277119	valid_0's binary_logloss: 0.328119
# [13]	valid_0's l2: 0.0722186	valid_0's l1: 0.264071	valid_0's binary_logloss: 0.310714
# [14]	valid_0's l2: 0.0661204	valid_0's l1: 0.251674	valid_0's binary_logloss: 0.294505
# [15]	valid_0's l2: 0.060627	valid_0's l1: 0.239894	valid_0's binary_logloss: 0.279393
# [16]	valid_0's l2: 0.0556787	valid_0's l1: 0.2287	valid_0's binary_logloss: 0.26529
# [17]	valid_0's l2: 0.0512218	valid_0's l1: 0.218062	valid_0's binary_logloss: 0.252117
# [18]	valid_0's l2: 0.0472081	valid_0's l1: 0.207951	valid_0's binary_logloss: 0.239802
# [19]	valid_0's l2: 0.0435939	valid_0's l1: 0.198341	valid_0's binary_logloss: 0.228281
# [20]	valid_0's l2: 0.0404294	valid_0's l1: 0.189442	valid_0's binary_logloss: 0.217786
# [21]	valid_0's l2: 0.0374927	valid_0's l1: 0.180751	valid_0's binary_logloss: 0.207671
# [22]	valid_0's l2: 0.0348494	valid_0's l1: 0.172489	valid_0's binary_logloss: 0.198192
# [23]	valid_0's l2: 0.0324707	valid_0's l1: 0.164634	valid_0's binary_logloss: 0.189304
# [24]	valid_0's l2: 0.0304028	valid_0's l1: 0.157375	valid_0's binary_logloss: 0.18122
# [25]	valid_0's l2: 0.0284718	valid_0's l1: 0.150268	valid_0's binary_logloss: 0.173388
# [26]	valid_0's l2: 0.0267353	valid_0's l1: 0.143511	valid_0's binary_logloss: 0.166036
# [27]	valid_0's l2: 0.025174	valid_0's l1: 0.137086	valid_0's binary_logloss: 0.159135
# [28]	valid_0's l2: 0.0237708	valid_0's l1: 0.130976	valid_0's binary_logloss: 0.152656
# [29]	valid_0's l2: 0.0225101	valid_0's l1: 0.125167	valid_0's binary_logloss: 0.146572
# [30]	valid_0's l2: 0.0213778	valid_0's l1: 0.119644	valid_0's binary_logloss: 0.140858
# [31]	valid_0's l2: 0.0202343	valid_0's l1: 0.114381	valid_0's binary_logloss: 0.134987
# [32]	valid_0's l2: 0.0193249	valid_0's l1: 0.109386	valid_0's binary_logloss: 0.129938
# [33]	valid_0's l2: 0.0185096	valid_0's l1: 0.104636	valid_0's binary_logloss: 0.125196
# [34]	valid_0's l2: 0.017779	valid_0's l1: 0.100119	valid_0's binary_logloss: 0.120744
# [35]	valid_0's l2: 0.0171549	valid_0's l1: 0.095957	valid_0's binary_logloss: 0.116715
# [36]	valid_0's l2: 0.0165667	valid_0's l1: 0.0918664	valid_0's binary_logloss: 0.112783
# [37]	valid_0's l2: 0.0160406	valid_0's l1: 0.0879762	valid_0's binary_logloss: 0.109094
# [38]	valid_0's l2: 0.0155703	valid_0's l1: 0.0842766	valid_0's binary_logloss: 0.105632
# [39]	valid_0's l2: 0.0151749	valid_0's l1: 0.080879	valid_0's binary_logloss: 0.10252
# [40]	valid_0's l2: 0.0146885	valid_0's l1: 0.077467	valid_0's binary_logloss: 0.0988775
# [41]	valid_0's l2: 0.0143563	valid_0's l1: 0.0742819	valid_0's binary_logloss: 0.0960152
# [42]	valid_0's l2: 0.0140606	valid_0's l1: 0.0712527	valid_0's binary_logloss: 0.0933341
# [43]	valid_0's l2: 0.0137979	valid_0's l1: 0.0683717	valid_0's binary_logloss: 0.0908242
# [44]	valid_0's l2: 0.013583	valid_0's l1: 0.0657359	valid_0's binary_logloss: 0.0885908
# [45]	valid_0's l2: 0.0133747	valid_0's l1: 0.0631254	valid_0's binary_logloss: 0.0863902
# [46]	valid_0's l2: 0.0131902	valid_0's l1: 0.0606425	valid_0's binary_logloss: 0.0843344
# [47]	valid_0's l2: 0.0130271	valid_0's l1: 0.058281	valid_0's binary_logloss: 0.0824157
# [48]	valid_0's l2: 0.0128983	valid_0's l1: 0.0561294	valid_0's binary_logloss: 0.0807297
# [49]	valid_0's l2: 0.0127703	valid_0's l1: 0.0539889	valid_0's binary_logloss: 0.0790585
# [50]	valid_0's l2: 0.0126578	valid_0's l1: 0.051953	valid_0's binary_logloss: 0.0775037
# [51]	valid_0's l2: 0.0125591	valid_0's l1: 0.0500164	valid_0's binary_logloss: 0.076059
# [52]	valid_0's l2: 0.0124017	valid_0's l1: 0.0481364	valid_0's binary_logloss: 0.0741206
# [53]	valid_0's l2: 0.0123294	valid_0's l1: 0.046386	valid_0's binary_logloss: 0.0728773
# [54]	valid_0's l2: 0.0122669	valid_0's l1: 0.044721	valid_0's binary_logloss: 0.0717278
# [55]	valid_0's l2: 0.0122131	valid_0's l1: 0.0431374	valid_0's binary_logloss: 0.0706673
# [56]	valid_0's l2: 0.012167	valid_0's l1: 0.041631	valid_0's binary_logloss: 0.0696911
# [57]	valid_0's l2: 0.0121279	valid_0's l1: 0.0401983	valid_0's binary_logloss: 0.0687948
# [58]	valid_0's l2: 0.0120355	valid_0's l1: 0.0388042	valid_0's binary_logloss: 0.0673755
# [59]	valid_0's l2: 0.0120104	valid_0's l1: 0.0375093	valid_0's binary_logloss: 0.0666253
# [60]	valid_0's l2: 0.0119899	valid_0's l1: 0.0362777	valid_0's binary_logloss: 0.0659434
# [61]	valid_0's l2: 0.0119789	valid_0's l1: 0.0351622	valid_0's binary_logloss: 0.0653855
# [62]	valid_0's l2: 0.0119658	valid_0's l1: 0.0340453	valid_0's binary_logloss: 0.0648271
# [63]	valid_0's l2: 0.0119559	valid_0's l1: 0.032983	valid_0's binary_logloss: 0.064327
# [64]	valid_0's l2: 0.0118995	valid_0's l1: 0.0319467	valid_0's binary_logloss: 0.0632824
# [65]	valid_0's l2: 0.011897	valid_0's l1: 0.0309866	valid_0's binary_logloss: 0.0628892
# [66]	valid_0's l2: 0.0118966	valid_0's l1: 0.0300735	valid_0's binary_logloss: 0.0625461
# [67]	valid_0's l2: 0.0118981	valid_0's l1: 0.0292048	valid_0's binary_logloss: 0.0622504
# [68]	valid_0's l2: 0.011901	valid_0's l1: 0.0283786	valid_0's binary_logloss: 0.0619999
# [69]	valid_0's l2: 0.0119052	valid_0's l1: 0.0275927	valid_0's binary_logloss: 0.0617922
# [70]	valid_0's l2: 0.0119132	valid_0's l1: 0.0268852	valid_0's binary_logloss: 0.0616669
# [71]	valid_0's l2: 0.0119192	valid_0's l1: 0.0261723	valid_0's binary_logloss: 0.0615366
# Early stopping, best iteration is:
# [66]	valid_0's l2: 0.0118966	valid_0's l1: 0.0300735	valid_0's binary_logloss: 0.0625461
# Starting predicting...
#               precision    recall  f1-score   support
#
#            0       0.97      0.20      0.33       162
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.20       163
#    macro avg       0.48      0.10      0.16       163
# weighted avg       0.96      0.20      0.33       163
#
# It has accuracy of 0.19631901840490798 AUC of 0.09876543209876543
# C:\Users\kylek\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kylek\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kylek\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
plotImp(gbm, X_train, num=20)
# Out:
#     Value     Feature
# 18    113    NO SHOES
# 17     98      WEIGHT
# 16     78  BODY FAT %
# 15     72    WINGSPAN
# 14     37       REACH
# 13     27    MAX VERT
# 12     25    STD VERT
# 11     18   WING DIFF
# 10     16  3/4 SPRINT
# 9      14       BENCH
# 8       8      HAND L
# 7       4      HAND W
# 6       3  after_2010
# 5       2      Pos_SG
# 4       2      Pos_PG
# 3       1     SHUTTLE
# 1       0      Pos_PF
# 2       0      Pos_SF
# 0       0       Pos_C

# %%
import shap
explainer = shap.TreeExplainer(gbm)
shap_values = explainer.shap_values(X_train)
shap.summary_plot(shap_values, X_train)
# Out:
# LightGBM binary classifier with TreeExplainer shap values output has changed to a list of ndarray

# %% [markdown]
# ### Loading in 2020 draft as time hold-out-test set

# %%
test_2021 = pd.read_pickle("2021_test.pkl")
test_2021 = test_2021[test_2021['MP']>250]
test_2021 = test_2021.drop(['Name','Season','through_4_years','MP'],axis=1)
test_2021 = pd.get_dummies(test_2021)
# Setting Avg_BPM >=0 as 1, and < 0 as 0
test_2021['Avg_BPM'] = (test_2021['Avg_BPM'] >= 0).astype(int)
#setting first year BPM >=0 as 1, and < 0 as 0.
test_2021['BPM'] = (test_2021['BPM'] >= 0).astype(int)

# %%
print("Upsampling training...")  
ros = RandomOverSampler(sampling_strategy='minority')
X_train, y_train = ros.fit_resample(four_years_df.drop(['BPM','Avg_BPM'],axis=1), four_years_df['BPM'])
X_test = test_2021.copy(deep=True).drop(['BPM','Avg_BPM'], axis=1)
y_test = test_2021['BPM']
# Out:
# Upsampling training...

# %%
lgb_train = lgb.Dataset(X_train, y_train)
lgb_eval = lgb.Dataset(X_test, y_test, reference=lgb_train)

# specify your configurations as a dict
params = {
    'boosting_type': 'gbdt',
    'objective': 'binary',
    'metric': {'l2', 'l1', "binary"},
  #  'metric': None,
    'num_leaves': 100,
    'learning_rate': 0.05,
    'feature_fraction': 0.9,
    'bagging_fraction': 0.8,
    'bagging_freq': 50,
    'verbose': -1
}

print('Starting training...')
# train
gbm = lgb.train(params,
                lgb_train,
             # feval=lgb_precision,
                num_boost_round=1000,
                valid_sets=lgb_eval,
                early_stopping_rounds=5)




print('Starting predicting...')
# predict
preds_proba = gbm.predict(X_test, num_iteration=gbm.best_iteration) 
fpr, tpr, thresholds = metrics.roc_curve(y_test,preds_proba)
J = tpr - fpr
ix = np.argmax(J)
best_thresh = thresholds[ix]
preds_best_cutoff = pd.Series(preds_proba).apply(lambda x: 1 if x > best_thresh else 0)
preds_best_cutoff = preds_best_cutoff.tolist()
a_score = accuracy_score(y_test, preds_best_cutoff)
auc_value = roc_auc_score(y_test, preds_best_cutoff)
print(classification_report(y_test,preds_best_cutoff))
print("It has accuracy of {} AUC of {}".format(a_score,auc_value))
# Out:
# Starting training...
# [1]	valid_0's l1: 0.491495	valid_0's binary_logloss: 0.676931	valid_0's l2: 0.241898
# Training until validation scores don't improve for 5 rounds
# [2]	valid_0's l1: 0.488966	valid_0's binary_logloss: 0.671937	valid_0's l2: 0.239414
# [3]	valid_0's l1: 0.47019	valid_0's binary_logloss: 0.636571	valid_0's l2: 0.221801
# [4]	valid_0's l1: 0.467972	valid_0's binary_logloss: 0.632684	valid_0's l2: 0.219923
# [5]	valid_0's l1: 0.450464	valid_0's binary_logloss: 0.601326	valid_0's l2: 0.204444
# [6]	valid_0's l1: 0.454024	valid_0's binary_logloss: 0.607752	valid_0's l2: 0.207697
# [7]	valid_0's l1: 0.459297	valid_0's binary_logloss: 0.618277	valid_0's l2: 0.213057
# [8]	valid_0's l1: 0.460782	valid_0's binary_logloss: 0.621618	valid_0's l2: 0.214795
# [9]	valid_0's l1: 0.464292	valid_0's binary_logloss: 0.63014	valid_0's l2: 0.219268
# [10]	valid_0's l1: 0.46843	valid_0's binary_logloss: 0.640768	valid_0's l2: 0.224844
# Early stopping, best iteration is:
# [5]	valid_0's l1: 0.450464	valid_0's binary_logloss: 0.601326	valid_0's l2: 0.204444
# Starting predicting...
#               precision    recall  f1-score   support
#
#            0       0.90      0.75      0.82        12
#            1       0.25      0.50      0.33         2
#
#     accuracy                           0.71        14
#    macro avg       0.57      0.62      0.58        14
# weighted avg       0.81      0.71      0.75        14
#
# It has accuracy of 0.7142857142857143 AUC of 0.625
